# %%
from LoadData import *
from MyFunctions import *
from Activation import *
from Variables import *
from Layer import *
from NeuralNetwork import *
from Training import *
from SetNetwork import *
from Testing import *
from Scoring import *
from clustering import *

import sys
import io
import json
import numpy as np
import pandas as pd
import math
import random
import pickle
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
def process_csv(file_path):
    data = pd.read_csv(file_path)
    
    data = score_data_df(data, best_model, x_main_train, x_main_val)
    data = cluster_my_data_df()

    output_csv = io.StringIO()
    data.to_csv(output_csv, index=False)
    
    # Move to the beginning of the StringIO object
    output_csv.seek(0)
    
    return output_csv.getvalue()

# %%
# Load pretrained model
with open('Trained_Network', 'rb') as config_dictionary_file:
    best_model = pickle.load(config_dictionary_file)

x_main_train = pd.read_csv("train_data_for_training.csv").to_numpy()[:,1:]
x_main_val = pd.read_csv("valid_data_for_validation.csv").to_numpy()[:,1:]

# %%
file_path = 'Mouse5_09042019_sup.csv'
data = pd.read_csv(file_path, skiprows=[1])

data = score_data_df(data, best_model, x_main_train, x_main_val)
data = cluster_my_data_df(data)

data
# Out:
# c:\Users\Kyle\SleepProject\server\clustering.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_class['Delta_DFT_z'] = stats.zscore(x_class['Delta_raw'], ddof=1)
# c:\Users\Kyle\SleepProject\server\clustering.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_class['Theta_DFT_z'] = stats.zscore(x_class['Theta_raw'], ddof=1)
# c:\Users\Kyle\SleepProject\server\clustering.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# if __name__ == "__main__":
#     # Take multiple input file paths from command-line arguments
#     input_files = sys.argv[1:]
    
#     # Dictionary to store each file's processed CSV as a string
#     output_data = {}

#     for file_path in input_files:
#         # Process each file separately and store in output_data dictionary
#         file_name = os.path.basename(file_path)  # Get only the file name
#         processed_csv = process_csv(file_path)
#         output_data[file_name] = processed_csv

#     # Convert output data to JSON for easy parsing on the Node.js side
#     print(json.dumps(output_data))
